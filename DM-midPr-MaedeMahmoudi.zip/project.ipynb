# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/home/maede/Documents/computerbook/data_mining/Midterm_project/CKD.csv')

# %%
data.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm',
#        'cad', 'appet', 'pe', 'ane', 'class'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# id         0
# age        9
# bp        12
# sg        47
# al        46
# su        49
# rbc      152
# pc        65
# pcc        4
# ba         4
# bgr       44
# bu        19
# sc        17
# sod       87
# pot       88
# hemo      52
# pcv       71
# wbcc     106
# rbcc     131
# htn        0
# dm         0
# cad        0
# appet      1
# pe         0
# ane        0
# class      0
# dtype: int64

# %%
data['age']
# Out:
# 0      48.0
# 1       7.0
# 2      62.0
# 3      48.0
# 4      51.0
#        ...
# 395    55.0
# 396    42.0
# 397    12.0
# 398    17.0
# 399    58.0
# Name: age, Length: 400, dtype: float64

# %%
data['bp']
# Out:
# 0      80.0
# 1      50.0
# 2      80.0
# 3      70.0
# 4      80.0
#        ...
# 395    80.0
# 396    70.0
# 397    80.0
# 398    60.0
# 399    80.0
# Name: bp, Length: 400, dtype: float64

# %%
data['age'] = pd.to_numeric(data['age'], errors='coerce')

# %%
data['bp'] = pd.to_numeric(data['bp'], errors='coerce')

# %%
data
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      1  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      2   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      3  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      4  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      5  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  396  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  397  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  398  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  399  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  400  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...   pcv    wbcc  rbcc    htn     dm    cad  appet     pe  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      400 non-null    int64
#  1   age     391 non-null    float64
#  2   bp      388 non-null    float64
#  3   sg      353 non-null    float64
#  4   al      354 non-null    float64
#  5   su      351 non-null    float64
#  6   rbc     248 non-null    object
#  7   pc      335 non-null    object
#  8   pcc     396 non-null    object
#  9   ba      396 non-null    object
#  10  bgr     356 non-null    float64
#  11  bu      381 non-null    float64
#  12  sc      383 non-null    float64
#  13  sod     313 non-null    float64
#  14  pot     312 non-null    float64
#  15  hemo    348 non-null    float64
#  16  pcv     329 non-null    float64
#  17  wbcc    294 non-null    float64
#  18  rbcc    269 non-null    float64
#  19  htn     400 non-null    bool
#  20  dm      400 non-null    bool
# ...

# %%
numeric_cols = ['age', 'bp', 'bgr', 'bu',
                'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']

for col in numeric_cols:
    if col in data.columns and data[col].dtype == 'object':  
        data[col] = pd.to_numeric(data[col], errors='coerce')  



data[numeric_cols].dtypes
data[numeric_cols].isna().sum()
# Out:
# age       9
# bp       12
# bgr      44
# bu       19
# sc       17
# sod      87
# pot      88
# hemo     52
# pcv      71
# wbcc    106
# rbcc    131
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      400 non-null    int64
#  1   age     391 non-null    float64
#  2   bp      388 non-null    float64
#  3   sg      353 non-null    float64
#  4   al      354 non-null    float64
#  5   su      351 non-null    float64
#  6   rbc     248 non-null    object
#  7   pc      335 non-null    object
#  8   pcc     396 non-null    object
#  9   ba      396 non-null    object
#  10  bgr     356 non-null    float64
#  11  bu      381 non-null    float64
#  12  sc      383 non-null    float64
#  13  sod     313 non-null    float64
#  14  pot     312 non-null    float64
#  15  hemo    348 non-null    float64
#  16  pcv     329 non-null    float64
#  17  wbcc    294 non-null    float64
#  18  rbcc    269 non-null    float64
#  19  htn     400 non-null    bool
#  20  dm      400 non-null    bool
# ...

# %%
bool_cols = ['ane', 'pe', 'cad', 'dm', 'htn']

for col in bool_cols:
    if col in data.columns:  
        data[col] = data[col].astype(bool)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      400 non-null    int64
#  1   age     391 non-null    float64
#  2   bp      388 non-null    float64
#  3   sg      353 non-null    float64
#  4   al      354 non-null    float64
#  5   su      351 non-null    float64
#  6   rbc     248 non-null    object
#  7   pc      335 non-null    object
#  8   pcc     396 non-null    object
#  9   ba      396 non-null    object
#  10  bgr     356 non-null    float64
#  11  bu      381 non-null    float64
#  12  sc      383 non-null    float64
#  13  sod     313 non-null    float64
#  14  pot     312 non-null    float64
#  15  hemo    348 non-null    float64
#  16  pcv     329 non-null    float64
#  17  wbcc    294 non-null    float64
#  18  rbcc    269 non-null    float64
#  19  htn     400 non-null    bool
#  20  dm      400 non-null    bool
# ...

# %%
int_cols = ['age' , 'bp' , 'su' , 'bgr' , 'bu' , 'sod' , 'pcv' , 'wbcc' ] 

for col in int_cols:
    if col in data.columns:
         data[col] = pd.to_numeric(data[col], errors='coerce').round().astype('Int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      400 non-null    int64
#  1   age     391 non-null    Int64
#  2   bp      388 non-null    Int64
#  3   sg      353 non-null    float64
#  4   al      354 non-null    float64
#  5   su      351 non-null    Int64
#  6   rbc     248 non-null    object
#  7   pc      335 non-null    object
#  8   pcc     396 non-null    object
#  9   ba      396 non-null    object
#  10  bgr     356 non-null    Int64
#  11  bu      381 non-null    Int64
#  12  sc      383 non-null    float64
#  13  sod     313 non-null    Int64
#  14  pot     312 non-null    float64
#  15  hemo    348 non-null    float64
#  16  pcv     329 non-null    Int64
#  17  wbcc    294 non-null    Int64
#  18  rbcc    269 non-null    float64
#  19  htn     400 non-null    bool
#  20  dm      400 non-null    bool
# ...

# %%
nominal_cols = ['sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'appet', 'class']  

for col in nominal_cols:
    if col in data.columns: 
        data[col] = data[col].astype('category')  

data[nominal_cols].dtypes
# Out:
# sg       category
# al       category
# su       category
# rbc      category
# pc       category
# pcc      category
# ba       category
# appet    category
# class    category
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      400 non-null    int64
#  1   age     391 non-null    Int64
#  2   bp      388 non-null    Int64
#  3   sg      353 non-null    category
#  4   al      354 non-null    category
#  5   su      351 non-null    category
#  6   rbc     248 non-null    category
#  7   pc      335 non-null    category
#  8   pcc     396 non-null    category
#  9   ba      396 non-null    category
#  10  bgr     356 non-null    Int64
#  11  bu      381 non-null    Int64
#  12  sc      383 non-null    float64
#  13  sod     313 non-null    Int64
#  14  pot     312 non-null    float64
#  15  hemo    348 non-null    float64
#  16  pcv     329 non-null    Int64
#  17  wbcc    294 non-null    Int64
#  18  rbcc    269 non-null    float64
#  19  htn     400 non-null    bool
#  20  dm      400 non-null    bool
# ...

# %%
data[numeric_cols].hist(figsize=(20, 10), layout=(4, 4), bins=20, color = 'orange')  
plt.tight_layout()  
plt.show()

# %%
sns.histplot(data=data, x='hemo', kde=True, color='purple', bins=15)
plt.title('distribution of homogolobin with distro line')
plt.show()

# %%
sns.histplot(data=data, x='age', hue='class', multiple='stack', palette='viridis')
plt.title('Age distribution based on disease class')
plt.show()

# %%
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title('missing value heatmap')
plt.show()

# %%
corr_matrix = data.select_dtypes(include=['float64', 'Int64']).corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, 
            annot=True, 
            fmt=".2f",   
            cmap='coolwarm', 
            linewidths=0.5)
plt.title('heat map for numeric attr')
plt.show()

# %%
plt.figure(figsize=(20, 15))  
sns.heatmap(corr_matrix, mask=mask, annot=True, cmap='viridis', 
            annot_kws={'size': 20})  
plt.tight_layout()
plt.show()

# %%
data = data.replace('?' , np.nan)

# %%
data
# Out:
#       id  age  bp     sg   al su     rbc        pc         pcc          ba  \
# 0      1   48  80  1.020  1.0  0     NaN    normal  notpresent  notpresent
# 1      2    7  50  1.020  4.0  0     NaN    normal  notpresent  notpresent
# 2      3   62  80  1.010  2.0  3  normal    normal  notpresent  notpresent
# 3      4   48  70  1.005  4.0  0  normal  abnormal     present  notpresent
# 4      5   51  80  1.010  2.0  0  normal    normal  notpresent  notpresent
# ..   ...  ...  ..    ...  ... ..     ...       ...         ...         ...
# 395  396   55  80  1.020  0.0  0  normal    normal  notpresent  notpresent
# 396  397   42  70  1.025  0.0  0  normal    normal  notpresent  notpresent
# 397  398   12  80  1.020  0.0  0  normal    normal  notpresent  notpresent
# 398  399   17  60  1.025  0.0  0  normal    normal  notpresent  notpresent
# 399  400   58  80  1.025  0.0  0  normal    normal  notpresent  notpresent
#
# ...

# %%
data.to_csv('data.csv', index=False, na_rep='Nan')

# %%
binary_cols = ['htn', 'dm', 'pe', 'ane', 'cad'] 

for col in binary_cols:  
    if col in data.columns:  
        data[col] = data[col].replace({True: 1, False: 0})

# %%
data['htn']
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 395    0
# 396    0
# 397    0
# 398    0
# 399    0
# Name: htn, Length: 400, dtype: int64

# %%
data.to_csv('data.csv', index=False, na_rep='NaN')

# %%
threshold_percentage = 0.4  
threshold_value = len(data) * threshold_percentage  

nan_counts = data.isna().sum()  

columns_to_drop = nan_counts[nan_counts > threshold_value].index  

cleaned_data = data.drop(columns=columns_to_drop)  

print("Data before cleaning:")  
data
print("\nColumns to drop:")  
columns_to_drop.tolist()
print("\nData after cleaning:")  
cleaned_data  
data.to_csv('data.csv', index=False, na_rep='Nan')
# Out:
# Data before cleaning:
#       id  age  bp     sg   al su     rbc        pc         pcc          ba  \
# 0      1   48  80  1.020  1.0  0     NaN    normal  notpresent  notpresent
# 1      2    7  50  1.020  4.0  0     NaN    normal  notpresent  notpresent
# 2      3   62  80  1.010  2.0  3  normal    normal  notpresent  notpresent
# 3      4   48  70  1.005  4.0  0  normal  abnormal     present  notpresent
# 4      5   51  80  1.010  2.0  0  normal    normal  notpresent  notpresent
# ..   ...  ...  ..    ...  ... ..     ...       ...         ...         ...
# 395  396   55  80  1.020  0.0  0  normal    normal  notpresent  notpresent
# 396  397   42  70  1.025  0.0  0  normal    normal  notpresent  notpresent
# 397  398   12  80  1.020  0.0  0  normal    normal  notpresent  notpresent
# 398  399   17  60  1.025  0.0  0  normal    normal  notpresent  notpresent
# 399  400   58  80  1.025  0.0  0  normal    normal  notpresent  notpresent
#
# ...

# %%
numeric_cols = ['age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']
for col in numeric_cols:
    data[col].fillna(round(data[col].median() , 3), inplace=True)

# %%
data
# Out:
#       id  age  bp     sg   al su     rbc        pc         pcc          ba  \
# 0      1   48  80  1.020  1.0  0     NaN    normal  notpresent  notpresent
# 1      2    7  50  1.020  4.0  0     NaN    normal  notpresent  notpresent
# 2      3   62  80  1.010  2.0  3  normal    normal  notpresent  notpresent
# 3      4   48  70  1.005  4.0  0  normal  abnormal     present  notpresent
# 4      5   51  80  1.010  2.0  0  normal    normal  notpresent  notpresent
# ..   ...  ...  ..    ...  ... ..     ...       ...         ...         ...
# 395  396   55  80  1.020  0.0  0  normal    normal  notpresent  notpresent
# 396  397   42  70  1.025  0.0  0  normal    normal  notpresent  notpresent
# 397  398   12  80  1.020  0.0  0  normal    normal  notpresent  notpresent
# 398  399   17  60  1.025  0.0  0  normal    normal  notpresent  notpresent
# 399  400   58  80  1.025  0.0  0  normal    normal  notpresent  notpresent
#
#      ...  pcv  wbcc  rbcc  htn  dm  cad  appet  pe  ane   class
# ...

# %%
data.to_csv('data.csv', index=False, na_rep='Nan')

# %%
nominal_cols = ['sg','al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'class']

data = data.copy()

for col in nominal_cols:
    if col in data.columns:
        mode_value = data[col].mode()[0]
        data[col] = data[col].fillna(mode_value)

# %%
data
# Out:
#       id  age  bp     sg   al su     rbc        pc         pcc          ba  \
# 0      1   48  80  1.020  1.0  0  normal    normal  notpresent  notpresent
# 1      2    7  50  1.020  4.0  0  normal    normal  notpresent  notpresent
# 2      3   62  80  1.010  2.0  3  normal    normal  notpresent  notpresent
# 3      4   48  70  1.005  4.0  0  normal  abnormal     present  notpresent
# 4      5   51  80  1.010  2.0  0  normal    normal  notpresent  notpresent
# ..   ...  ...  ..    ...  ... ..     ...       ...         ...         ...
# 395  396   55  80  1.020  0.0  0  normal    normal  notpresent  notpresent
# 396  397   42  70  1.025  0.0  0  normal    normal  notpresent  notpresent
# 397  398   12  80  1.020  0.0  0  normal    normal  notpresent  notpresent
# 398  399   17  60  1.025  0.0  0  normal    normal  notpresent  notpresent
# 399  400   58  80  1.025  0.0  0  normal    normal  notpresent  notpresent
#
#      ...  pcv  wbcc  rbcc  htn  dm  cad  appet  pe  ane   class
# ...

# %%
data.to_csv('data.csv', index=False)

# %%
numeric_cols = ['age' , 'bp' , 'bgr' , 'bu' , 'sc' , 'sod' , 'pot' , 'hemo' , 'pcv' , 'wbcc' , 'rbcc']   

for col in numeric_cols : 
    if col in data.columns:
        q1 = data[col].quantile(0.25)
        q3 = data[col].quantile(0.75)
        irq = q3 - q1
        lower_bound = q1 - 1.5*irq
        upper_bound = q3 + 1.5*irq
        data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]

# %%
data
# Out:
#       id  age  bp     sg   al su     rbc      pc         pcc          ba  ...  \
# 0      1   48  80  1.020  1.0  0  normal  normal  notpresent  notpresent  ...
# 4      5   51  80  1.010  2.0  0  normal  normal  notpresent  notpresent  ...
# 5      6   60  90  1.015  3.0  0  normal  normal  notpresent  notpresent  ...
# 16    17   47  70  1.015  2.0  0  normal  normal  notpresent  notpresent  ...
# 23    24   21  70  1.010  0.0  0  normal  normal  notpresent  notpresent  ...
# ..   ...  ...  ..    ...  ... ..     ...     ...         ...         ...  ...
# 394  395   50  80  1.020  0.0  0  normal  normal  notpresent  notpresent  ...
# 396  397   42  70  1.025  0.0  0  normal  normal  notpresent  notpresent  ...
# 397  398   12  80  1.020  0.0  0  normal  normal  notpresent  notpresent  ...
# 398  399   17  60  1.025  0.0  0  normal  normal  notpresent  notpresent  ...
# 399  400   58  80  1.025  0.0  0  normal  normal  notpresent  notpresent  ...
#
# ...

# %%
len(data)
# Out:
# 205

# %%
plt.figure(figsize = (15 , 10))
sns.boxplot(data = data[numeric_cols])
plt.xticks(rotation = 45)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

numeric_cols = ['age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']

scaler = MinMaxScaler(feature_range=(0, 1))  

data[numeric_cols] = scaler.fit_transform(data[numeric_cols])
data.to_csv('data.csv', index=False)

#original_data = scaler.inverse_transform(data[numeric_cols])

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()


data['rbc_encoded'] = encoder.fit_transform(data['rbc'])
data['pc_encoded'] = encoder.fit_transform(data['pc'])
data['pcc_encoded'] = encoder.fit_transform(data['pcc'])
data['ba_encoded'] = encoder.fit_transform(data['ba'])
data['appet_encoded'] = encoder.fit_transform(data['appet'])
data['class_encoded'] = encoder.fit_transform(data['class'])

# %%
data
# Out:
#       id       age        bp     sg   al su     rbc      pc         pcc  \
# 0      1  0.536232  0.666667  1.020  1.0  0  normal  normal  notpresent
# 4      5  0.579710  0.666667  1.010  2.0  0  normal  normal  notpresent
# 5      6  0.710145  1.000000  1.015  3.0  0  normal  normal  notpresent
# 16    17  0.521739  0.333333  1.015  2.0  0  normal  normal  notpresent
# 23    24  0.144928  0.333333  1.010  0.0  0  normal  normal  notpresent
# ..   ...       ...       ...    ...  ... ..     ...     ...         ...
# 394  395  0.565217  0.666667  1.020  0.0  0  normal  normal  notpresent
# 396  397  0.449275  0.333333  1.025  0.0  0  normal  normal  notpresent
# 397  398  0.014493  0.666667  1.020  0.0  0  normal  normal  notpresent
# 398  399  0.086957  0.000000  1.025  0.0  0  normal  normal  notpresent
# 399  400  0.681159  0.666667  1.025  0.0  0  normal  normal  notpresent
#
#              ba  ...  appet  pe  ane   class  rbc_encoded  pc_encoded  \
# ...

# %%
data.to_csv('data.csv' , index = False )

# %%
nominal_cols = ['rbc' , 'pc' , 'appet']
data_encoded = pd.get_dummies(
    data,
    columns = nominal_cols,
    prefix = nominal_cols,
    drop_first = True
)

# %%
data_encoded.head()
# Out:
#     id       age        bp     sg   al su         pcc          ba       bgr  \
# 0    1  0.536232  0.666667  1.020  1.0  0  notpresent  notpresent  0.364286
# 4    5  0.579710  0.666667  1.010  2.0  0  notpresent  notpresent  0.257143
# 5    6  0.710145  1.000000  1.015  3.0  0  notpresent  notpresent  0.028571
# 16  17  0.521739  0.333333  1.015  2.0  0  notpresent  notpresent  0.207143
# 23  24  0.144928  0.333333  1.010  0.0  0  notpresent  notpresent  0.364286
#
#           bu  ...  class  rbc_encoded  pc_encoded  pcc_encoded  ba_encoded  \
# 0   0.333333  ...    ckd            1           1            0           0
# 4   0.205128  ...    ckd            1           1            0           0
# 5   0.192308  ...    ckd            1           1            0           0
# 16  0.461538  ...    ckd            1           1            0           0
# 23  0.410256  ...    ckd            1           1            0           0
#
# ...

# %%
data_encoded.to_csv('data.csv', index=False)

# %%
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205 entries, 0 to 399
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             205 non-null    int64
#  1   age            205 non-null    float64
#  2   bp             205 non-null    float64
#  3   sg             205 non-null    category
#  4   al             205 non-null    category
#  5   su             205 non-null    category
#  6   pcc            205 non-null    category
#  7   ba             205 non-null    category
#  8   bgr            205 non-null    float64
#  9   bu             205 non-null    float64
#  10  sc             205 non-null    float64
#  11  sod            205 non-null    float64
#  12  pot            205 non-null    float64
#  13  hemo           205 non-null    float64
#  14  pcv            205 non-null    float64
#  15  wbcc           205 non-null    float64
#  16  rbcc           205 non-null    float64
# ...

# %%
numeric_data = data.select_dtypes(include=['number'])

correlation_matrix = numeric_data.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt='.2f', 
            annot_kws={"size": 10}) 
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_data = pca.fit_transform(data[numeric_cols])

 
pca.explained_variance_ratio_
# Out:
# array([0.27627126, 0.15533052])

# %%
pca_df = pd.DataFrame(data=pca_data, columns=['PC1', 'PC2'])
print(pca_df.head())
# Out:
#         PC1       PC2
# 0  0.037200 -0.203176
# 1  0.496387 -0.032610
# 2  0.433155 -0.468036
# 3  0.372955  0.264117
# 4  0.147606  0.216934

# %%
color_list = ['red', 'green', 'blue', 'orange']
colors = [color_list[i % len(color_list)] for i in numeric_data['class_encoded']]

plt.scatter(pca_data[:, 0], pca_data[:, 1], c=colors, cmap='viridis', edgecolor='k', s=50)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('result')
plt.show()
# Out:
# /tmp/ipykernel_2933/225902339.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(pca_data[:, 0], pca_data[:, 1], c=colors, cmap='viridis', edgecolor='k', s=50)
